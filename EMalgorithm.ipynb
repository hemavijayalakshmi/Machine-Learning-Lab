# %% [markdown]
# <a href="https://colab.research.google.com/github/hemavijayalakshmi/Machine-Learning-Lab/blob/main/EMalgorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# Load the heart disease dataset
data = pd.read_csv("heart_disease.csv")

# Select relevant features for clustering
features = data[['age', 'cholesterol', 'blood_pressure', 'max_heart_rate']]  # Example features

# Normalize the data for better clustering
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Apply K-Means clustering
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans_labels = kmeans.fit_predict(scaled_features)

# Apply EM algorithm (Gaussian Mixture Model)
gmm = GaussianMixture(n_components=2, random_state=42)
gmm_labels = gmm.fit_predict(scaled_features)

# Evaluate clustering quality using silhouette score
kmeans_score = silhouette_score(scaled_features, kmeans_labels)
gmm_score = silhouette_score(scaled_features, gmm_labels)

# Print results
print(f"K-Means Silhouette Score: {kmeans_score:.4f}")
print(f"EM (GMM) Silhouette Score: {gmm_score:.4f}")

# Compare cluster assignments
data['KMeans_Cluster'] = kmeans_labels
data['EM_Cluster'] = gmm_labels
print(data[['KMeans_Cluster', 'EM_Cluster']].head())
# Out:
# K-Means Silhouette Score: 0.5340
# EM (GMM) Silhouette Score: 0.5340
#    KMeans_Cluster  EM_Cluster
# 0               0           0
# 1               0           0
# 2               1           1
# 3               0           0
# 4               1           1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# Load the heart disease dataset
data = pd.read_csv("heart_disease.csv")

# Select relevant features for clustering
features = data[['age', 'cholesterol', 'blood_pressure', 'max_heart_rate']]  # Example features

# Normalize the data for better clustering
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Apply K-Means clustering
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans_labels = kmeans.fit_predict(scaled_features)

# Apply EM algorithm (Gaussian Mixture Model)
gmm = GaussianMixture(n_components=2, random_state=42)
gmm_labels = gmm.fit_predict(scaled_features)

# Evaluate clustering quality using silhouette score
kmeans_score = silhouette_score(scaled_features, kmeans_labels)
gmm_score = silhouette_score(scaled_features, gmm_labels)

# Print silhouette scores
print(f"K-Means Silhouette Score: {kmeans_score:.4f}")
print(f"EM (GMM) Silhouette Score: {gmm_score:.4f}")

# Plotting K-Means Clustering Results
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.scatter(scaled_features[:, 0], scaled_features[:, 1], c=kmeans_labels, cmap='viridis', marker='o')
plt.title("K-Means Clustering")
plt.xlabel('Feature 1 (Age)')
plt.ylabel('Feature 2 (Cholesterol)')

# Plotting EM (GMM) Clustering Results
plt.subplot(1, 2, 2)
plt.scatter(scaled_features[:, 0], scaled_features[:, 1], c=gmm_labels, cmap='viridis', marker='x')
plt.title("EM (GMM) Clustering")
plt.xlabel('Feature 1 (Age)')
plt.ylabel('Feature 2 (Cholesterol)')

plt.tight_layout()
plt.show()

# Compare cluster assignments
data['KMeans_Cluster'] = kmeans_labels
data['EM_Cluster'] = gmm_labels
print(data[['KMeans_Cluster', 'EM_Cluster']].head())
# Out:
# K-Means Silhouette Score: 0.5340
# EM (GMM) Silhouette Score: 0.5340
#    KMeans_Cluster  EM_Cluster
# 0               0           0
# 1               0           0
# 2               1           1
# 3               0           0
# 4               1           1
